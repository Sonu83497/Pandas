# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Creating a DataFrame

# %%
data = {
    'Name': ['sonu','pankaj','gaurav','anuj'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age      City  Salary
# 0    sonu   28  New York   65000
# 1  pankaj   34     Paris   70000
# 2  gaurav   29    Berlin   62000
# 3    anuj   42    London   85000

# %%
data_list = [
    ['Sonu', 28, 'New York', 65000],
    ['anuj', 34, 'Paris', 70000],
    ['pankaj', 29, 'Berlin', 62000],
    ['gaurav', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns=columns)

# %%
df2
# Out:
#      Name  Age      City  Salary
# 0    Sonu   28  New York   65000
# 1    anuj   34     Paris   70000
# 2  pankaj   29    Berlin   62000
# 3  gaurav   42    London   85000

# %% [markdown]
# ### Selection and indexing of Columns

# %%
df2
# Out:
#      Name  Age      City  Salary
# 0    Sonu   28  New York   65000
# 1    anuj   34     Paris   70000
# 2  pankaj   29    Berlin   62000
# 3  gaurav   42    London   85000

# %%
df2['Name']
# Out:
# 0      Sonu
# 1      anuj
# 2    pankaj
# 3    gaurav
# Name: Name, dtype: str

# %%
df2['City']
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: str

# %%
df2[["Name","Salary"]]
# Out:
#      Name  Salary
# 0    Sonu   65000
# 1    anuj   70000
# 2  pankaj   62000
# 3  gaurav   85000

# %% [markdown]
# ### Creating a new column

# %%
df2["Designation"] = ["Engineer","CA","Doctor","Engineer"]

# %%
df2
# Out:
#      Name  Age      City  Salary Designation
# 0    Sonu   28  New York   65000    Engineer
# 1    anuj   34     Paris   70000          CA
# 2  pankaj   29    Berlin   62000      Doctor
# 3  gaurav   42    London   85000    Engineer

# %% [markdown]
# ### Removing Column

# %%
df2.drop("Designation",axis=1)
# Out:
#      Name  Age      City  Salary
# 0    Sonu   28  New York   65000
# 1    anuj   34     Paris   70000
# 2  pankaj   29    Berlin   62000
# 3  gaurav   42    London   85000

# %%
df2
# Out:
#      Name  Age      City  Salary Designation
# 0    Sonu   28  New York   65000    Engineer
# 1    anuj   34     Paris   70000          CA
# 2  pankaj   29    Berlin   62000      Doctor
# 3  gaurav   42    London   85000    Engineer

# %%
df2.drop("Designation",axis=1,inplace=True)

# %%
df2
# Out:
#      Name  Age      City  Salary
# 0    Sonu   28  New York   65000
# 1    anuj   34     Paris   70000
# 2  pankaj   29    Berlin   62000
# 3  gaurav   42    London   85000

# %%
df2.drop(["City","Salary"],axis=1)
# Out:
#      Name  Age
# 0    Sonu   28
# 1    anuj   34
# 2  pankaj   29
# 3  gaurav   42

# %%
df2.drop(1,axis=0)
# Out:
#      Name  Age      City  Salary
# 0    Sonu   28  New York   65000
# 2  pankaj   29    Berlin   62000
# 3  gaurav   42    London   85000

# %%
df2
# Out:
#      Name  Age      City  Salary
# 0    Sonu   28  New York   65000
# 1    anuj   34     Paris   70000
# 2  pankaj   29    Berlin   62000
# 3  gaurav   42    London   85000

# %% [markdown]
# ### Selecting Rows

# %%
df2
# Out:
#      Name  Age      City  Salary
# 0    Sonu   28  New York   65000
# 1    anuj   34     Paris   70000
# 2  pankaj   29    Berlin   62000
# 3  gaurav   42    London   85000

# %%
df2.loc[0]
# Out:
# Name          Sonu
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df2.loc[[0,2]]
# Out:
#      Name  Age      City  Salary
# 0    Sonu   28  New York   65000
# 2  pankaj   29    Berlin   62000

# %%
df2.iloc[3]
# Out:
# Name      gaurav
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %% [markdown]
# ### Selcting Subsets of Rows and Columns

# %%
df2
# Out:
#      Name  Age      City  Salary
# 0    Sonu   28  New York   65000
# 1    anuj   34     Paris   70000
# 2  pankaj   29    Berlin   62000
# 3  gaurav   42    London   85000

# %%
df.loc[[0,1]][['City','Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2.loc[[2,3]][['Age','City']]
# Out:
#    Age    City
# 2   29  Berlin
# 3   42  London

# %%
df2.loc[[1,2]][['Age','City']]
# Out:
#    Age    City
# 1   34   Paris
# 2   29  Berlin

# %% [markdown]
# ### Conditional Selection

# %%
df2
# Out:
#      Name  Age      City  Salary
# 0    Sonu   28  New York   65000
# 1    anuj   34     Paris   70000
# 2  pankaj   29    Berlin   62000
# 3  gaurav   42    London   85000

# %%
#  i only want to see those people whose age is above 30
df2[df2['Age'] > 30]
# Out:
#      Name  Age    City  Salary
# 1    anuj   34   Paris   70000
# 3  gaurav   42  London   85000

# %%
#  i only want to see whose age is above 30 and their city must be paris
df2[(df2["Age"] > 30) & (df2["City"] == 'Paris')]
# Out:
#    Name  Age   City  Salary
# 1  anuj   34  Paris   70000
